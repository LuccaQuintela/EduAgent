# %%
import logging
logging.basicConfig(level=logging.ERROR)
import warnings
warnings.filterwarnings("ignore")

from engine import Engine

# %%
engine = Engine(verbose=True)
await engine.start_class()
# Out:
# Session started for [bob]
# Session ID: f9cb0fff-392f-4852-9efe-a51372c9ad48
# State:
# {'active_curriculum': False, 'topic': None, 'user_wishes_to_exit': False}
#
# >>> User Query: hello
#   [Event] Author: central_agent, Type: Event, Final: False, Content: parts=[Part(
#   function_call=FunctionCall(
#     args={
#       'agent_name': 'interaction_agent'
#     },
#     id='adk-092fe9fb-20db-4bdb-b860-775fc2eee261',
#     name='transfer_to_agent'
#   )
# )] role='model'
#   [Event] Author: central_agent, Type: Event, Final: False, Content: parts=[Part(
#   function_response=FunctionResponse(
#     id='adk-092fe9fb-20db-4bdb-b860-775fc2eee261',
#     name='transfer_to_agent',
#     response={
#       'result': None
#     }
#   )
# )] role='user'
#   [Event] Author: interaction_agent, Type: Event, Final: True, Content: parts=[Part(
#   text="""Hi there! Ready to dive into some learning? Do you have a specific topic in mind, or would you like me to help you set up a curriculum?
# """
# ...
